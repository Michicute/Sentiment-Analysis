# %%
# !git clone https://github.com/Louis-udm/VGCN-BERT.git

# %%
# !pip install NLTK
# !pip install python-dotenv
# !pip install boto3
# !pip install -U sst
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 40.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.2/171.2 kB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sst: filename=sst-0.2.4-py3-none-any.whl size=72207 sha256=507cefecf4dd767b7296d52293d028b3ed2e727ffb41b0b386c711dde187d71c
#   Stored in directory: /root/.cache/pip/wheels/4e/0e/a2/30afeb8faf377a5bf73caa3a0303de19853714702538873289
# Successfully built sst
# ...

# %% [markdown]
# #Training

# %%
# %cd /content/drive/MyDrive/NLP/GROUP1 - SOURCE CODE - VGCN_BERT - OTHER/VGCN-BERT
# Out:
# /content/drive/MyDrive/NLP/GROUP1 - SOURCE CODE - VGCN_BERT - OTHER/VGCN-BERT

# %%
# !python -m vgcn_bert.prepare_data --ds sst
# Out:
# ---data prepare configure---
# Data set:  sst freq_min_for_word_choice 1 window_size 1000
# del_stop_words False use_bert_tokenizer_at_clean True
# tfidf-mode only_tf bert_model_scale bert-base-uncased bert_lower_case True
#
#
# Get the tweets,y,confidence etc from data file...
# SST-2, train_szie:6920, valid_size:872, test_size:1821
# Statistics for original text: max_len56,id9255, min_len2,id180, avg_len19.31
# Remove stop words from tweets...
# Stop_words: {}
# Use bert_tokenizer for seperate words to bert vocab
# 100% 231508/231508 [00:00<00:00, 1251691.80B/s]
# Total 0  docs are empty.
# After tokenizer:
# Min_len : 1 id: 1751
# Max_len : 65 id: 848
# Average_len : 21.35992926245709
# Build graph...
# Calculate First isomerous adj and First isomorphic vocab adj, get word-word PMI values
# Train_valid size: 7792 Window number: 7792
# max_pmi: 8.960852845322371 min_pmi: -2.9136554999391726
# max_npmi: 1.0 min_npmi: -0.32515381629775586
# Calculate doc-word tf-idf weight
# ...

# %%
# !python -m vgcn_bert.train_vanilla_vgcn_bert --ds sst
# Out:
# Vanilla_VGCN_BERT Start at: Mon Dec 18 10:49:41 2023
#
# ----- Configure -----
#   args.ds: sst
#   stop_words: False
#   Learning_rate0: 1e-05
#   weight_decay: 0.01
#   Loss_criterion cle
#   softmax_before_mse: True
#   Dropout: 0.2
#   Run_adj: pmi
#   gcn_act_func: Relu
#   MAX_SEQ_LENGTH: 200
#   perform_metrics_str: ['weighted avg', 'f1-score']
#   model_file_4save: Vanilla_VGCN_BERT1_model_sst_cle_sw0.pt
#   validate_program: False
#
# ----- Prepare data set -----
#   Load/shuffle/seperate sst dataset, and vocabulary graph adjacent matrix
# ...

# %% [markdown]
# #Testing

# %%
# prompt: kiểm tra path hiện tại
# %pwd
# Out:
# '/content/drive/MyDrive/NLP/VGCN-BERT/VGCN-BERT'

# %%
def make_predict(text):
    with open('data/SST-2/test.txt', 'r') as file:
        lines = file.readlines()
        lines[0] = f'{0} {text}\n'
    with open('data/SST-2/test.txt', 'w') as file:
        file.writelines(lines)
    # !python -m vgcn_bert.test_prepare_data --ds sst
    # !python -m vgcn_bert.test --ds sst --load 1 --number_test_case 1

# %%
make_predict('The actors perform not too good, but the scenes are shot perfect')
# Out:
# ---data prepare configure---
# Data set:  sst freq_min_for_word_choice 1 window_size 1000
# del_stop_words False use_bert_tokenizer_at_clean True
# tfidf-mode only_tf bert_model_scale bert-base-uncased bert_lower_case True
#
#
# Get the tweets,y,confidence etc from data file...
# SST-2, train_szie:6920, valid_size:872, test_size:1821
# Statistics for original text: max_len56,id8985, min_len2,id104, avg_len19.31
# Remove stop words from tweets...
# Stop_words: {}
# Use bert_tokenizer for seperate words to bert vocab
# Total 0  docs are empty.
# After tokenizer:
# Min_len : 1 id: 335
# Max_len : 65 id: 4890
# Average_len : 21.360137314053887
# Build graph...
# Calculate First isomerous adj and First isomorphic vocab adj, get word-word PMI values
# Train_valid size: 7792 Window number: 7792
# max_pmi: 8.960852845322371 min_pmi: -2.9136554999391726
# max_npmi: 1.0 min_npmi: -0.32515381629775586
# Calculate doc-word tf-idf weight
# ...
